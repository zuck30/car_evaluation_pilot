# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Group 9: Python & Data Science: Car evaluation dataset
# *This Notebook was written by Shadrack T. John* *https://thisisshadrack.netlify.app/* <br>

# %%
#Lets import the dataset we've downloaded from kaggle
df=pd.read_csv('car_evaluation.csv')

# %%
df.head()
# Out:
#    vhigh vhigh.1  2 2.1  small   low  unacc
# 0  vhigh   vhigh  2   2  small   med  unacc
# 1  vhigh   vhigh  2   2  small  high  unacc
# 2  vhigh   vhigh  2   2    med   low  unacc
# 3  vhigh   vhigh  2   2    med   med  unacc
# 4  vhigh   vhigh  2   2    med  high  unacc

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1727 entries, 0 to 1726
# Data columns (total 7 columns):
# vhigh      1727 non-null object
# vhigh.1    1727 non-null object
# 2          1727 non-null object
# 2.1        1727 non-null object
# small      1727 non-null object
# low        1727 non-null object
# unacc      1727 non-null object
# dtypes: object(7)
# memory usage: 94.5+ KB

# %%
len(df)
# Out:
# 1727

# %%
pd.options.display.max_rows
# Out:
# 100

# %%
#Let's update up to 100 max_rows
#pd.options.display.max_rows=200

# %%
df.head(100)
# Out:
#     vhigh vhigh.1      2   2.1  small   low  unacc
# 0   vhigh   vhigh      2     2  small   med  unacc
# 1   vhigh   vhigh      2     2  small  high  unacc
# 2   vhigh   vhigh      2     2    med   low  unacc
# 3   vhigh   vhigh      2     2    med   med  unacc
# 4   vhigh   vhigh      2     2    med  high  unacc
# 5   vhigh   vhigh      2     2    big   low  unacc
# 6   vhigh   vhigh      2     2    big   med  unacc
# 7   vhigh   vhigh      2     2    big  high  unacc
# 8   vhigh   vhigh      2     4  small   low  unacc
# 9   vhigh   vhigh      2     4  small   med  unacc
# 10  vhigh   vhigh      2     4  small  high  unacc
# 11  vhigh   vhigh      2     4    med   low  unacc
# 12  vhigh   vhigh      2     4    med   med  unacc
# 13  vhigh   vhigh      2     4    med  high  unacc
# 14  vhigh   vhigh      2     4    big   low  unacc
# 15  vhigh   vhigh      2     4    big   med  unacc
# 16  vhigh   vhigh      2     4    big  high  unacc
# 17  vhigh   vhigh      2  more  small   low  unacc
# 18  vhigh   vhigh      2  more  small   med  unacc
# 19  vhigh   vhigh      2  more  small  high  unacc
# 20  vhigh   vhigh      2  more    med   low  unacc
# 21  vhigh   vhigh      2  more    med   med  unacc
# 22  vhigh   vhigh      2  more    med  high  unacc
# 23  vhigh   vhigh      2  more    big   low  unacc
# 24  vhigh   vhigh      2  more    big   med  unacc
# 25  vhigh   vhigh      2  more    big  high  unacc
# 26  vhigh   vhigh      3     2  small   low  unacc
# 27  vhigh   vhigh      3     2  small   med  unacc
# 28  vhigh   vhigh      3     2  small  high  unacc
# 29  vhigh   vhigh      3     2    med   low  unacc
# 30  vhigh   vhigh      3     2    med   med  unacc
# 31  vhigh   vhigh      3     2    med  high  unacc
# 32  vhigh   vhigh      3     2    big   low  unacc
# 33  vhigh   vhigh      3     2    big   med  unacc
# 34  vhigh   vhigh      3     2    big  high  unacc
# 35  vhigh   vhigh      3     4  small   low  unacc
# 36  vhigh   vhigh      3     4  small   med  unacc
# 37  vhigh   vhigh      3     4  small  high  unacc
# 38  vhigh   vhigh      3     4    med   low  unacc
# 39  vhigh   vhigh      3     4    med   med  unacc
# 40  vhigh   vhigh      3     4    med  high  unacc
# 41  vhigh   vhigh      3     4    big   low  unacc
# 42  vhigh   vhigh      3     4    big   med  unacc
# 43  vhigh   vhigh      3     4    big  high  unacc
# 44  vhigh   vhigh      3  more  small   low  unacc
# 45  vhigh   vhigh      3  more  small   med  unacc
# 46  vhigh   vhigh      3  more  small  high  unacc
# 47  vhigh   vhigh      3  more    med   low  unacc
# 48  vhigh   vhigh      3  more    med   med  unacc
# 49  vhigh   vhigh      3  more    med  high  unacc
# 50  vhigh   vhigh      3  more    big   low  unacc
# 51  vhigh   vhigh      3  more    big   med  unacc
# 52  vhigh   vhigh      3  more    big  high  unacc
# 53  vhigh   vhigh      4     2  small   low  unacc
# 54  vhigh   vhigh      4     2  small   med  unacc
# 55  vhigh   vhigh      4     2  small  high  unacc
# 56  vhigh   vhigh      4     2    med   low  unacc
# 57  vhigh   vhigh      4     2    med   med  unacc
# 58  vhigh   vhigh      4     2    med  high  unacc
# 59  vhigh   vhigh      4     2    big   low  unacc
# 60  vhigh   vhigh      4     2    big   med  unacc
# 61  vhigh   vhigh      4     2    big  high  unacc
# 62  vhigh   vhigh      4     4  small   low  unacc
# 63  vhigh   vhigh      4     4  small   med  unacc
# 64  vhigh   vhigh      4     4  small  high  unacc
# 65  vhigh   vhigh      4     4    med   low  unacc
# 66  vhigh   vhigh      4     4    med   med  unacc
# 67  vhigh   vhigh      4     4    med  high  unacc
# 68  vhigh   vhigh      4     4    big   low  unacc
# 69  vhigh   vhigh      4     4    big   med  unacc
# 70  vhigh   vhigh      4     4    big  high  unacc
# 71  vhigh   vhigh      4  more  small   low  unacc
# 72  vhigh   vhigh      4  more  small   med  unacc
# 73  vhigh   vhigh      4  more  small  high  unacc
# 74  vhigh   vhigh      4  more    med   low  unacc
# 75  vhigh   vhigh      4  more    med   med  unacc
# 76  vhigh   vhigh      4  more    med  high  unacc
# 77  vhigh   vhigh      4  more    big   low  unacc
# 78  vhigh   vhigh      4  more    big   med  unacc
# 79  vhigh   vhigh      4  more    big  high  unacc
# 80  vhigh   vhigh  5more     2  small   low  unacc
# 81  vhigh   vhigh  5more     2  small   med  unacc
# 82  vhigh   vhigh  5more     2  small  high  unacc
# 83  vhigh   vhigh  5more     2    med   low  unacc
# 84  vhigh   vhigh  5more     2    med   med  unacc
# 85  vhigh   vhigh  5more     2    med  high  unacc
# 86  vhigh   vhigh  5more     2    big   low  unacc
# 87  vhigh   vhigh  5more     2    big   med  unacc
# 88  vhigh   vhigh  5more     2    big  high  unacc
# 89  vhigh   vhigh  5more     4  small   low  unacc
# 90  vhigh   vhigh  5more     4  small   med  unacc
# 91  vhigh   vhigh  5more     4  small  high  unacc
# 92  vhigh   vhigh  5more     4    med   low  unacc
# 93  vhigh   vhigh  5more     4    med   med  unacc
# 94  vhigh   vhigh  5more     4    med  high  unacc
# 95  vhigh   vhigh  5more     4    big   low  unacc
# 96  vhigh   vhigh  5more     4    big   med  unacc
# 97  vhigh   vhigh  5more     4    big  high  unacc
# 98  vhigh   vhigh  5more  more  small   low  unacc
# 99  vhigh   vhigh  5more  more  small   med  unacc

# %%
## So far we have a ploblem, columns that doesn't make any sense, we also have more, 5more no_of doors. 
## This can be solved by mapping.
## Mapping string values to numerical values
## Before that I should rename the columns, they need to make sense before all that

# %%
df=df.rename(columns= {'buying':'vhigh', 'vhigh.1': 'maintenance','2' : 'doors', '2.1': 'persons'  ,'small':'lug_boot', 'low': 'safety', 'unacc': 'class'})

# %%
df.head(1)
# Out:
#    vhigh maintenance doors persons lug_boot safety  class
# 0  vhigh       vhigh     2       2    small    med  unacc

# %%
## Let's save this dataset so far
df.to_csv('modified_car_evaluation.csv')

# %%
## Checking if changes applied..
df.head(3)
# Out:
#    vhigh maintenance doors persons lug_boot safety  class
# 0  vhigh       vhigh     2       2    small    med  unacc
# 1  vhigh       vhigh     2       2    small   high  unacc
# 2  vhigh       vhigh     2       2      med    low  unacc

# %%
## Lets add the row we renamed as the first row in a new dataset
new_row = {'buying': 'vhigh', 'maintenance': 'vhigh', 'doors': 2, 'persons': '2', 'lugboot': 'small', 'safety': 'low', 'class': 'unacc'}

# %%
insert_index = 0

# %%
new_df = pd.DataFrame([new_row])

# %%
## Split the original DataFrame into two parts and insert the new row in between
df = pd.concat([df.iloc[:insert_index], new_df, df.iloc[insert_index:]], ignore_index=True, sort=True)

# %%
## Create a DataFrame from the new row
new_df = pd.DataFrame([new_row])

# %%
## Concatenate the new DataFrame with the existing DataFrame
df = pd.concat([new_df, df], ignore_index=True, sort=True)

# %%
# Append the new row at the top
df = pd.concat([pd.DataFrame(new_row, index=[0]), df], ignore_index=True, sort=True)

# %%
df
# Out:
#      buying  class  doors lug_boot lugboot maintenance persons safety  vhigh
# 0     vhigh  unacc      2      NaN   small       vhigh       2    low    NaN
# 1     vhigh  unacc      2      NaN   small       vhigh       2    low    NaN
# 2     vhigh  unacc      2      NaN   small       vhigh       2    low    NaN
# 3       NaN  unacc      2    small     NaN       vhigh       2    med  vhigh
# 4       NaN  unacc      2    small     NaN       vhigh       2   high  vhigh
# 5       NaN  unacc      2      med     NaN       vhigh       2    low  vhigh
# 6       NaN  unacc      2      med     NaN       vhigh       2    med  vhigh
# 7       NaN  unacc      2      med     NaN       vhigh       2   high  vhigh
# 8       NaN  unacc      2      big     NaN       vhigh       2    low  vhigh
# 9       NaN  unacc      2      big     NaN       vhigh       2    med  vhigh
# 10      NaN  unacc      2      big     NaN       vhigh       2   high  vhigh
# 11      NaN  unacc      2    small     NaN       vhigh       4    low  vhigh
# 12      NaN  unacc      2    small     NaN       vhigh       4    med  vhigh
# 13      NaN  unacc      2    small     NaN       vhigh       4   high  vhigh
# 14      NaN  unacc      2      med     NaN       vhigh       4    low  vhigh
# 15      NaN  unacc      2      med     NaN       vhigh       4    med  vhigh
# 16      NaN  unacc      2      med     NaN       vhigh       4   high  vhigh
# 17      NaN  unacc      2      big     NaN       vhigh       4    low  vhigh
# 18      NaN  unacc      2      big     NaN       vhigh       4    med  vhigh
# 19      NaN  unacc      2      big     NaN       vhigh       4   high  vhigh
# 20      NaN  unacc      2    small     NaN       vhigh    more    low  vhigh
# 21      NaN  unacc      2    small     NaN       vhigh    more    med  vhigh
# 22      NaN  unacc      2    small     NaN       vhigh    more   high  vhigh
# 23      NaN  unacc      2      med     NaN       vhigh    more    low  vhigh
# 24      NaN  unacc      2      med     NaN       vhigh    more    med  vhigh
# 25      NaN  unacc      2      med     NaN       vhigh    more   high  vhigh
# 26      NaN  unacc      2      big     NaN       vhigh    more    low  vhigh
# 27      NaN  unacc      2      big     NaN       vhigh    more    med  vhigh
# 28      NaN  unacc      2      big     NaN       vhigh    more   high  vhigh
# 29      NaN  unacc      3    small     NaN       vhigh       2    low  vhigh
# 30      NaN  unacc      3    small     NaN       vhigh       2    med  vhigh
# 31      NaN  unacc      3    small     NaN       vhigh       2   high  vhigh
# 32      NaN  unacc      3      med     NaN       vhigh       2    low  vhigh
# 33      NaN  unacc      3      med     NaN       vhigh       2    med  vhigh
# 34      NaN  unacc      3      med     NaN       vhigh       2   high  vhigh
# 35      NaN  unacc      3      big     NaN       vhigh       2    low  vhigh
# 36      NaN  unacc      3      big     NaN       vhigh       2    med  vhigh
# 37      NaN  unacc      3      big     NaN       vhigh       2   high  vhigh
# 38      NaN  unacc      3    small     NaN       vhigh       4    low  vhigh
# 39      NaN  unacc      3    small     NaN       vhigh       4    med  vhigh
# 40      NaN  unacc      3    small     NaN       vhigh       4   high  vhigh
# 41      NaN  unacc      3      med     NaN       vhigh       4    low  vhigh
# 42      NaN  unacc      3      med     NaN       vhigh       4    med  vhigh
# 43      NaN  unacc      3      med     NaN       vhigh       4   high  vhigh
# 44      NaN  unacc      3      big     NaN       vhigh       4    low  vhigh
# 45      NaN  unacc      3      big     NaN       vhigh       4    med  vhigh
# 46      NaN  unacc      3      big     NaN       vhigh       4   high  vhigh
# 47      NaN  unacc      3    small     NaN       vhigh    more    low  vhigh
# 48      NaN  unacc      3    small     NaN       vhigh    more    med  vhigh
# 49      NaN  unacc      3    small     NaN       vhigh    more   high  vhigh
# ...     ...    ...    ...      ...     ...         ...     ...    ...    ...
# 1680    NaN  unacc      4      med     NaN         low       2    med    low
# 1681    NaN  unacc      4      med     NaN         low       2   high    low
# 1682    NaN  unacc      4      big     NaN         low       2    low    low
# 1683    NaN  unacc      4      big     NaN         low       2    med    low
# 1684    NaN  unacc      4      big     NaN         low       2   high    low
# 1685    NaN  unacc      4    small     NaN         low       4    low    low
# 1686    NaN    acc      4    small     NaN         low       4    med    low
# 1687    NaN   good      4    small     NaN         low       4   high    low
# 1688    NaN  unacc      4      med     NaN         low       4    low    low
# 1689    NaN   good      4      med     NaN         low       4    med    low
# 1690    NaN  vgood      4      med     NaN         low       4   high    low
# 1691    NaN  unacc      4      big     NaN         low       4    low    low
# 1692    NaN   good      4      big     NaN         low       4    med    low
# 1693    NaN  vgood      4      big     NaN         low       4   high    low
# 1694    NaN  unacc      4    small     NaN         low    more    low    low
# 1695    NaN    acc      4    small     NaN         low    more    med    low
# 1696    NaN   good      4    small     NaN         low    more   high    low
# 1697    NaN  unacc      4      med     NaN         low    more    low    low
# 1698    NaN   good      4      med     NaN         low    more    med    low
# 1699    NaN  vgood      4      med     NaN         low    more   high    low
# 1700    NaN  unacc      4      big     NaN         low    more    low    low
# 1701    NaN   good      4      big     NaN         low    more    med    low
# 1702    NaN  vgood      4      big     NaN         low    more   high    low
# 1703    NaN  unacc  5more    small     NaN         low       2    low    low
# 1704    NaN  unacc  5more    small     NaN         low       2    med    low
# 1705    NaN  unacc  5more    small     NaN         low       2   high    low
# 1706    NaN  unacc  5more      med     NaN         low       2    low    low
# 1707    NaN  unacc  5more      med     NaN         low       2    med    low
# 1708    NaN  unacc  5more      med     NaN         low       2   high    low
# 1709    NaN  unacc  5more      big     NaN         low       2    low    low
# 1710    NaN  unacc  5more      big     NaN         low       2    med    low
# 1711    NaN  unacc  5more      big     NaN         low       2   high    low
# 1712    NaN  unacc  5more    small     NaN         low       4    low    low
# 1713    NaN    acc  5more    small     NaN         low       4    med    low
# 1714    NaN   good  5more    small     NaN         low       4   high    low
# 1715    NaN  unacc  5more      med     NaN         low       4    low    low
# 1716    NaN   good  5more      med     NaN         low       4    med    low
# 1717    NaN  vgood  5more      med     NaN         low       4   high    low
# 1718    NaN  unacc  5more      big     NaN         low       4    low    low
# 1719    NaN   good  5more      big     NaN         low       4    med    low
# 1720    NaN  vgood  5more      big     NaN         low       4   high    low
# 1721    NaN  unacc  5more    small     NaN         low    more    low    low
# 1722    NaN    acc  5more    small     NaN         low    more    med    low
# 1723    NaN   good  5more    small     NaN         low    more   high    low
# 1724    NaN  unacc  5more      med     NaN         low    more    low    low
# 1725    NaN   good  5more      med     NaN         low    more    med    low
# 1726    NaN  vgood  5more      med     NaN         low    more   high    low
# 1727    NaN  unacc  5more      big     NaN         low    more    low    low
# 1728    NaN   good  5more      big     NaN         low    more    med    low
# 1729    NaN  vgood  5more      big     NaN         low    more   high    low
#
# [1730 rows x 9 columns]

# %%
## Defining mapping for numerical values
doors_mapping = {'2': 2,'3':3, '4':4, '5more': 5}
df['doors'] = df['doors'].map(doors_mapping)

# %%
## Handling '5more'
df['doors'] = df['doors'].replace('5more', 5)
## Now, the 'doors' column contains numerical values

# %%
df.head(200)
# Out:
#     buying  class  doors lug_boot lugboot maintenance persons safety  vhigh
# 0    vhigh  unacc    NaN      NaN   small       vhigh       2    low    NaN
# 1    vhigh  unacc    NaN      NaN   small       vhigh       2    low    NaN
# 2    vhigh  unacc    NaN      NaN   small       vhigh       2    low    NaN
# 3      NaN  unacc    2.0    small     NaN       vhigh       2    med  vhigh
# 4      NaN  unacc    2.0    small     NaN       vhigh       2   high  vhigh
# 5      NaN  unacc    2.0      med     NaN       vhigh       2    low  vhigh
# 6      NaN  unacc    2.0      med     NaN       vhigh       2    med  vhigh
# 7      NaN  unacc    2.0      med     NaN       vhigh       2   high  vhigh
# 8      NaN  unacc    2.0      big     NaN       vhigh       2    low  vhigh
# 9      NaN  unacc    2.0      big     NaN       vhigh       2    med  vhigh
# 10     NaN  unacc    2.0      big     NaN       vhigh       2   high  vhigh
# 11     NaN  unacc    2.0    small     NaN       vhigh       4    low  vhigh
# 12     NaN  unacc    2.0    small     NaN       vhigh       4    med  vhigh
# 13     NaN  unacc    2.0    small     NaN       vhigh       4   high  vhigh
# 14     NaN  unacc    2.0      med     NaN       vhigh       4    low  vhigh
# 15     NaN  unacc    2.0      med     NaN       vhigh       4    med  vhigh
# 16     NaN  unacc    2.0      med     NaN       vhigh       4   high  vhigh
# 17     NaN  unacc    2.0      big     NaN       vhigh       4    low  vhigh
# 18     NaN  unacc    2.0      big     NaN       vhigh       4    med  vhigh
# 19     NaN  unacc    2.0      big     NaN       vhigh       4   high  vhigh
# 20     NaN  unacc    2.0    small     NaN       vhigh    more    low  vhigh
# 21     NaN  unacc    2.0    small     NaN       vhigh    more    med  vhigh
# 22     NaN  unacc    2.0    small     NaN       vhigh    more   high  vhigh
# 23     NaN  unacc    2.0      med     NaN       vhigh    more    low  vhigh
# 24     NaN  unacc    2.0      med     NaN       vhigh    more    med  vhigh
# 25     NaN  unacc    2.0      med     NaN       vhigh    more   high  vhigh
# 26     NaN  unacc    2.0      big     NaN       vhigh    more    low  vhigh
# 27     NaN  unacc    2.0      big     NaN       vhigh    more    med  vhigh
# 28     NaN  unacc    2.0      big     NaN       vhigh    more   high  vhigh
# 29     NaN  unacc    3.0    small     NaN       vhigh       2    low  vhigh
# 30     NaN  unacc    3.0    small     NaN       vhigh       2    med  vhigh
# 31     NaN  unacc    3.0    small     NaN       vhigh       2   high  vhigh
# 32     NaN  unacc    3.0      med     NaN       vhigh       2    low  vhigh
# 33     NaN  unacc    3.0      med     NaN       vhigh       2    med  vhigh
# 34     NaN  unacc    3.0      med     NaN       vhigh       2   high  vhigh
# 35     NaN  unacc    3.0      big     NaN       vhigh       2    low  vhigh
# 36     NaN  unacc    3.0      big     NaN       vhigh       2    med  vhigh
# 37     NaN  unacc    3.0      big     NaN       vhigh       2   high  vhigh
# 38     NaN  unacc    3.0    small     NaN       vhigh       4    low  vhigh
# 39     NaN  unacc    3.0    small     NaN       vhigh       4    med  vhigh
# 40     NaN  unacc    3.0    small     NaN       vhigh       4   high  vhigh
# 41     NaN  unacc    3.0      med     NaN       vhigh       4    low  vhigh
# 42     NaN  unacc    3.0      med     NaN       vhigh       4    med  vhigh
# 43     NaN  unacc    3.0      med     NaN       vhigh       4   high  vhigh
# 44     NaN  unacc    3.0      big     NaN       vhigh       4    low  vhigh
# 45     NaN  unacc    3.0      big     NaN       vhigh       4    med  vhigh
# 46     NaN  unacc    3.0      big     NaN       vhigh       4   high  vhigh
# 47     NaN  unacc    3.0    small     NaN       vhigh    more    low  vhigh
# 48     NaN  unacc    3.0    small     NaN       vhigh    more    med  vhigh
# 49     NaN  unacc    3.0    small     NaN       vhigh    more   high  vhigh
# ..     ...    ...    ...      ...     ...         ...     ...    ...    ...
# 150    NaN  unacc    3.0      med     NaN        high       4    med  vhigh
# 151    NaN  unacc    3.0      med     NaN        high       4   high  vhigh
# 152    NaN  unacc    3.0      big     NaN        high       4    low  vhigh
# 153    NaN  unacc    3.0      big     NaN        high       4    med  vhigh
# 154    NaN  unacc    3.0      big     NaN        high       4   high  vhigh
# 155    NaN  unacc    3.0    small     NaN        high    more    low  vhigh
# 156    NaN  unacc    3.0    small     NaN        high    more    med  vhigh
# 157    NaN  unacc    3.0    small     NaN        high    more   high  vhigh
# 158    NaN  unacc    3.0      med     NaN        high    more    low  vhigh
# 159    NaN  unacc    3.0      med     NaN        high    more    med  vhigh
# 160    NaN  unacc    3.0      med     NaN        high    more   high  vhigh
# 161    NaN  unacc    3.0      big     NaN        high    more    low  vhigh
# 162    NaN  unacc    3.0      big     NaN        high    more    med  vhigh
# 163    NaN  unacc    3.0      big     NaN        high    more   high  vhigh
# 164    NaN  unacc    4.0    small     NaN        high       2    low  vhigh
# 165    NaN  unacc    4.0    small     NaN        high       2    med  vhigh
# 166    NaN  unacc    4.0    small     NaN        high       2   high  vhigh
# 167    NaN  unacc    4.0      med     NaN        high       2    low  vhigh
# 168    NaN  unacc    4.0      med     NaN        high       2    med  vhigh
# 169    NaN  unacc    4.0      med     NaN        high       2   high  vhigh
# 170    NaN  unacc    4.0      big     NaN        high       2    low  vhigh
# 171    NaN  unacc    4.0      big     NaN        high       2    med  vhigh
# 172    NaN  unacc    4.0      big     NaN        high       2   high  vhigh
# 173    NaN  unacc    4.0    small     NaN        high       4    low  vhigh
# 174    NaN  unacc    4.0    small     NaN        high       4    med  vhigh
# 175    NaN  unacc    4.0    small     NaN        high       4   high  vhigh
# 176    NaN  unacc    4.0      med     NaN        high       4    low  vhigh
# 177    NaN  unacc    4.0      med     NaN        high       4    med  vhigh
# 178    NaN  unacc    4.0      med     NaN        high       4   high  vhigh
# 179    NaN  unacc    4.0      big     NaN        high       4    low  vhigh
# 180    NaN  unacc    4.0      big     NaN        high       4    med  vhigh
# 181    NaN  unacc    4.0      big     NaN        high       4   high  vhigh
# 182    NaN  unacc    4.0    small     NaN        high    more    low  vhigh
# 183    NaN  unacc    4.0    small     NaN        high    more    med  vhigh
# 184    NaN  unacc    4.0    small     NaN        high    more   high  vhigh
# 185    NaN  unacc    4.0      med     NaN        high    more    low  vhigh
# 186    NaN  unacc    4.0      med     NaN        high    more    med  vhigh
# 187    NaN  unacc    4.0      med     NaN        high    more   high  vhigh
# 188    NaN  unacc    4.0      big     NaN        high    more    low  vhigh
# 189    NaN  unacc    4.0      big     NaN        high    more    med  vhigh
# 190    NaN  unacc    4.0      big     NaN        high    more   high  vhigh
# 191    NaN  unacc    5.0    small     NaN        high       2    low  vhigh
# 192    NaN  unacc    5.0    small     NaN        high       2    med  vhigh
# 193    NaN  unacc    5.0    small     NaN        high       2   high  vhigh
# 194    NaN  unacc    5.0      med     NaN        high       2    low  vhigh
# 195    NaN  unacc    5.0      med     NaN        high       2    med  vhigh
# 196    NaN  unacc    5.0      med     NaN        high       2   high  vhigh
# 197    NaN  unacc    5.0      big     NaN        high       2    low  vhigh
# 198    NaN  unacc    5.0      big     NaN        high       2    med  vhigh
# 199    NaN  unacc    5.0      big     NaN        high       2   high  vhigh
#
# [200 rows x 9 columns]

# %%
## What's left to deal with is 'more' value in 'persons' column without specifying an exact number 
## can be a bit more challenging since there's no clear numerical information provided.

# %%
df
# Out:
#      buying  class  doors lug_boot lugboot maintenance persons safety  vhigh
# 0     vhigh  unacc    NaN      NaN   small       vhigh       2    low    NaN
# 1     vhigh  unacc    NaN      NaN   small       vhigh       2    low    NaN
# 2     vhigh  unacc    NaN      NaN   small       vhigh       2    low    NaN
# 3       NaN  unacc    2.0    small     NaN       vhigh       2    med  vhigh
# 4       NaN  unacc    2.0    small     NaN       vhigh       2   high  vhigh
# 5       NaN  unacc    2.0      med     NaN       vhigh       2    low  vhigh
# 6       NaN  unacc    2.0      med     NaN       vhigh       2    med  vhigh
# 7       NaN  unacc    2.0      med     NaN       vhigh       2   high  vhigh
# 8       NaN  unacc    2.0      big     NaN       vhigh       2    low  vhigh
# 9       NaN  unacc    2.0      big     NaN       vhigh       2    med  vhigh
# 10      NaN  unacc    2.0      big     NaN       vhigh       2   high  vhigh
# 11      NaN  unacc    2.0    small     NaN       vhigh       4    low  vhigh
# 12      NaN  unacc    2.0    small     NaN       vhigh       4    med  vhigh
# 13      NaN  unacc    2.0    small     NaN       vhigh       4   high  vhigh
# 14      NaN  unacc    2.0      med     NaN       vhigh       4    low  vhigh
# 15      NaN  unacc    2.0      med     NaN       vhigh       4    med  vhigh
# 16      NaN  unacc    2.0      med     NaN       vhigh       4   high  vhigh
# 17      NaN  unacc    2.0      big     NaN       vhigh       4    low  vhigh
# 18      NaN  unacc    2.0      big     NaN       vhigh       4    med  vhigh
# 19      NaN  unacc    2.0      big     NaN       vhigh       4   high  vhigh
# 20      NaN  unacc    2.0    small     NaN       vhigh    more    low  vhigh
# 21      NaN  unacc    2.0    small     NaN       vhigh    more    med  vhigh
# 22      NaN  unacc    2.0    small     NaN       vhigh    more   high  vhigh
# 23      NaN  unacc    2.0      med     NaN       vhigh    more    low  vhigh
# 24      NaN  unacc    2.0      med     NaN       vhigh    more    med  vhigh
# 25      NaN  unacc    2.0      med     NaN       vhigh    more   high  vhigh
# 26      NaN  unacc    2.0      big     NaN       vhigh    more    low  vhigh
# 27      NaN  unacc    2.0      big     NaN       vhigh    more    med  vhigh
# 28      NaN  unacc    2.0      big     NaN       vhigh    more   high  vhigh
# 29      NaN  unacc    3.0    small     NaN       vhigh       2    low  vhigh
# 30      NaN  unacc    3.0    small     NaN       vhigh       2    med  vhigh
# 31      NaN  unacc    3.0    small     NaN       vhigh       2   high  vhigh
# 32      NaN  unacc    3.0      med     NaN       vhigh       2    low  vhigh
# 33      NaN  unacc    3.0      med     NaN       vhigh       2    med  vhigh
# 34      NaN  unacc    3.0      med     NaN       vhigh       2   high  vhigh
# 35      NaN  unacc    3.0      big     NaN       vhigh       2    low  vhigh
# 36      NaN  unacc    3.0      big     NaN       vhigh       2    med  vhigh
# 37      NaN  unacc    3.0      big     NaN       vhigh       2   high  vhigh
# 38      NaN  unacc    3.0    small     NaN       vhigh       4    low  vhigh
# 39      NaN  unacc    3.0    small     NaN       vhigh       4    med  vhigh
# 40      NaN  unacc    3.0    small     NaN       vhigh       4   high  vhigh
# 41      NaN  unacc    3.0      med     NaN       vhigh       4    low  vhigh
# 42      NaN  unacc    3.0      med     NaN       vhigh       4    med  vhigh
# 43      NaN  unacc    3.0      med     NaN       vhigh       4   high  vhigh
# 44      NaN  unacc    3.0      big     NaN       vhigh       4    low  vhigh
# 45      NaN  unacc    3.0      big     NaN       vhigh       4    med  vhigh
# 46      NaN  unacc    3.0      big     NaN       vhigh       4   high  vhigh
# 47      NaN  unacc    3.0    small     NaN       vhigh    more    low  vhigh
# 48      NaN  unacc    3.0    small     NaN       vhigh    more    med  vhigh
# 49      NaN  unacc    3.0    small     NaN       vhigh    more   high  vhigh
# ...     ...    ...    ...      ...     ...         ...     ...    ...    ...
# 1680    NaN  unacc    4.0      med     NaN         low       2    med    low
# 1681    NaN  unacc    4.0      med     NaN         low       2   high    low
# 1682    NaN  unacc    4.0      big     NaN         low       2    low    low
# 1683    NaN  unacc    4.0      big     NaN         low       2    med    low
# 1684    NaN  unacc    4.0      big     NaN         low       2   high    low
# 1685    NaN  unacc    4.0    small     NaN         low       4    low    low
# 1686    NaN    acc    4.0    small     NaN         low       4    med    low
# 1687    NaN   good    4.0    small     NaN         low       4   high    low
# 1688    NaN  unacc    4.0      med     NaN         low       4    low    low
# 1689    NaN   good    4.0      med     NaN         low       4    med    low
# 1690    NaN  vgood    4.0      med     NaN         low       4   high    low
# 1691    NaN  unacc    4.0      big     NaN         low       4    low    low
# 1692    NaN   good    4.0      big     NaN         low       4    med    low
# 1693    NaN  vgood    4.0      big     NaN         low       4   high    low
# 1694    NaN  unacc    4.0    small     NaN         low    more    low    low
# 1695    NaN    acc    4.0    small     NaN         low    more    med    low
# 1696    NaN   good    4.0    small     NaN         low    more   high    low
# 1697    NaN  unacc    4.0      med     NaN         low    more    low    low
# 1698    NaN   good    4.0      med     NaN         low    more    med    low
# 1699    NaN  vgood    4.0      med     NaN         low    more   high    low
# 1700    NaN  unacc    4.0      big     NaN         low    more    low    low
# 1701    NaN   good    4.0      big     NaN         low    more    med    low
# 1702    NaN  vgood    4.0      big     NaN         low    more   high    low
# 1703    NaN  unacc    5.0    small     NaN         low       2    low    low
# 1704    NaN  unacc    5.0    small     NaN         low       2    med    low
# 1705    NaN  unacc    5.0    small     NaN         low       2   high    low
# 1706    NaN  unacc    5.0      med     NaN         low       2    low    low
# 1707    NaN  unacc    5.0      med     NaN         low       2    med    low
# 1708    NaN  unacc    5.0      med     NaN         low       2   high    low
# 1709    NaN  unacc    5.0      big     NaN         low       2    low    low
# 1710    NaN  unacc    5.0      big     NaN         low       2    med    low
# 1711    NaN  unacc    5.0      big     NaN         low       2   high    low
# 1712    NaN  unacc    5.0    small     NaN         low       4    low    low
# 1713    NaN    acc    5.0    small     NaN         low       4    med    low
# 1714    NaN   good    5.0    small     NaN         low       4   high    low
# 1715    NaN  unacc    5.0      med     NaN         low       4    low    low
# 1716    NaN   good    5.0      med     NaN         low       4    med    low
# 1717    NaN  vgood    5.0      med     NaN         low       4   high    low
# 1718    NaN  unacc    5.0      big     NaN         low       4    low    low
# 1719    NaN   good    5.0      big     NaN         low       4    med    low
# 1720    NaN  vgood    5.0      big     NaN         low       4   high    low
# 1721    NaN  unacc    5.0    small     NaN         low    more    low    low
# 1722    NaN    acc    5.0    small     NaN         low    more    med    low
# 1723    NaN   good    5.0    small     NaN         low    more   high    low
# 1724    NaN  unacc    5.0      med     NaN         low    more    low    low
# 1725    NaN   good    5.0      med     NaN         low    more    med    low
# 1726    NaN  vgood    5.0      med     NaN         low    more   high    low
# 1727    NaN  unacc    5.0      big     NaN         low    more    low    low
# 1728    NaN   good    5.0      big     NaN         low    more    med    low
# 1729    NaN  vgood    5.0      big     NaN         low    more   high    low
#
# [1730 rows x 9 columns]

# %%
## Checking for null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1730 entries, 0 to 1729
# Data columns (total 9 columns):
# buying         3 non-null object
# class          1730 non-null object
# doors          1727 non-null float64
# lug_boot       1727 non-null object
# lugboot        3 non-null object
# maintenance    1730 non-null object
# persons        1730 non-null object
# safety         1730 non-null object
# vhigh          1727 non-null object
# dtypes: float64(1), object(8)
# memory usage: 121.7+ KB

# %%
df.isna()
#df.isna().count()
# Out:
#       buying  class  doors  lug_boot  lugboot  maintenance  persons  safety  \
# 0      False  False   True      True    False        False    False   False
# 1      False  False   True      True    False        False    False   False
# 2      False  False   True      True    False        False    False   False
# 3       True  False  False     False     True        False    False   False
# 4       True  False  False     False     True        False    False   False
# 5       True  False  False     False     True        False    False   False
# 6       True  False  False     False     True        False    False   False
# 7       True  False  False     False     True        False    False   False
# 8       True  False  False     False     True        False    False   False
# 9       True  False  False     False     True        False    False   False
# 10      True  False  False     False     True        False    False   False
# 11      True  False  False     False     True        False    False   False
# 12      True  False  False     False     True        False    False   False
# 13      True  False  False     False     True        False    False   False
# 14      True  False  False     False     True        False    False   False
# 15      True  False  False     False     True        False    False   False
# 16      True  False  False     False     True        False    False   False
# 17      True  False  False     False     True        False    False   False
# 18      True  False  False     False     True        False    False   False
# 19      True  False  False     False     True        False    False   False
# 20      True  False  False     False     True        False    False   False
# 21      True  False  False     False     True        False    False   False
# 22      True  False  False     False     True        False    False   False
# 23      True  False  False     False     True        False    False   False
# 24      True  False  False     False     True        False    False   False
# 25      True  False  False     False     True        False    False   False
# 26      True  False  False     False     True        False    False   False
# 27      True  False  False     False     True        False    False   False
# 28      True  False  False     False     True        False    False   False
# 29      True  False  False     False     True        False    False   False
# 30      True  False  False     False     True        False    False   False
# 31      True  False  False     False     True        False    False   False
# 32      True  False  False     False     True        False    False   False
# 33      True  False  False     False     True        False    False   False
# 34      True  False  False     False     True        False    False   False
# 35      True  False  False     False     True        False    False   False
# 36      True  False  False     False     True        False    False   False
# 37      True  False  False     False     True        False    False   False
# 38      True  False  False     False     True        False    False   False
# 39      True  False  False     False     True        False    False   False
# 40      True  False  False     False     True        False    False   False
# 41      True  False  False     False     True        False    False   False
# 42      True  False  False     False     True        False    False   False
# 43      True  False  False     False     True        False    False   False
# 44      True  False  False     False     True        False    False   False
# 45      True  False  False     False     True        False    False   False
# 46      True  False  False     False     True        False    False   False
# 47      True  False  False     False     True        False    False   False
# 48      True  False  False     False     True        False    False   False
# 49      True  False  False     False     True        False    False   False
# ...      ...    ...    ...       ...      ...          ...      ...     ...
# 1680    True  False  False     False     True        False    False   False
# 1681    True  False  False     False     True        False    False   False
# 1682    True  False  False     False     True        False    False   False
# 1683    True  False  False     False     True        False    False   False
# 1684    True  False  False     False     True        False    False   False
# 1685    True  False  False     False     True        False    False   False
# 1686    True  False  False     False     True        False    False   False
# 1687    True  False  False     False     True        False    False   False
# 1688    True  False  False     False     True        False    False   False
# 1689    True  False  False     False     True        False    False   False
# 1690    True  False  False     False     True        False    False   False
# 1691    True  False  False     False     True        False    False   False
# 1692    True  False  False     False     True        False    False   False
# 1693    True  False  False     False     True        False    False   False
# 1694    True  False  False     False     True        False    False   False
# 1695    True  False  False     False     True        False    False   False
# 1696    True  False  False     False     True        False    False   False
# 1697    True  False  False     False     True        False    False   False
# 1698    True  False  False     False     True        False    False   False
# 1699    True  False  False     False     True        False    False   False
# 1700    True  False  False     False     True        False    False   False
# 1701    True  False  False     False     True        False    False   False
# 1702    True  False  False     False     True        False    False   False
# 1703    True  False  False     False     True        False    False   False
# 1704    True  False  False     False     True        False    False   False
# 1705    True  False  False     False     True        False    False   False
# 1706    True  False  False     False     True        False    False   False
# 1707    True  False  False     False     True        False    False   False
# 1708    True  False  False     False     True        False    False   False
# 1709    True  False  False     False     True        False    False   False
# 1710    True  False  False     False     True        False    False   False
# 1711    True  False  False     False     True        False    False   False
# 1712    True  False  False     False     True        False    False   False
# 1713    True  False  False     False     True        False    False   False
# 1714    True  False  False     False     True        False    False   False
# 1715    True  False  False     False     True        False    False   False
# 1716    True  False  False     False     True        False    False   False
# 1717    True  False  False     False     True        False    False   False
# 1718    True  False  False     False     True        False    False   False
# 1719    True  False  False     False     True        False    False   False
# 1720    True  False  False     False     True        False    False   False
# 1721    True  False  False     False     True        False    False   False
# 1722    True  False  False     False     True        False    False   False
# 1723    True  False  False     False     True        False    False   False
# 1724    True  False  False     False     True        False    False   False
# 1725    True  False  False     False     True        False    False   False
# 1726    True  False  False     False     True        False    False   False
# 1727    True  False  False     False     True        False    False   False
# 1728    True  False  False     False     True        False    False   False
# 1729    True  False  False     False     True        False    False   False
#
#       vhigh
# 0      True
# 1      True
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# ...     ...
# 1680  False
# 1681  False
# 1682  False
# 1683  False
# 1684  False
# 1685  False
# 1686  False
# 1687  False
# 1688  False
# 1689  False
# 1690  False
# 1691  False
# 1692  False
# 1693  False
# 1694  False
# 1695  False
# 1696  False
# 1697  False
# 1698  False
# 1699  False
# 1700  False
# 1701  False
# 1702  False
# 1703  False
# 1704  False
# 1705  False
# 1706  False
# 1707  False
# 1708  False
# 1709  False
# 1710  False
# 1711  False
# 1712  False
# 1713  False
# 1714  False
# 1715  False
# 1716  False
# 1717  False
# 1718  False
# 1719  False
# 1720  False
# 1721  False
# 1722  False
# 1723  False
# 1724  False
# 1725  False
# 1726  False
# 1727  False
# 1728  False
# 1729  False
#
# [1730 rows x 9 columns]

# %%
## Double checking
pd.isnull(None)
# Out:
# True

# %%
## I have no null values
## Good to go Cive :) Smile..

# %% [markdown]
# As all the columns are categorical, check for unique values of each column

# %%
for i in df.columns:
    print(df[i].unique(),"\t",df[i].nunique())
  ## Print unique values && and count..
# Out:
# ['vhigh' 'high' 'med' 'low'] 	 4
# ['vhigh' 'high' 'med' 'low'] 	 4
# [2 3 4 5] 	 4
# ['2' '4' 'more'] 	 3
# ['small' 'med' 'big'] 	 3
# ['med' 'high' 'low'] 	 3
# ['unacc' 'acc' 'vgood' 'good'] 	 4

# %%
## ['vhigh' 'high' 'med' 'low']: This column contains 4 unique values: 
## 'vhigh,' 'high,' 'med,' and 'low,' and each of these values has a count of 4 as in the output above.
## [2 3 4 5]: This column contains 4 unique values: 2, 3, 4, and 5, and each of these values has a count of 4 pia.
## ['2' '4' 'more']: This column contains 3 unique values: '2,' '4,' and 'more,' 
##and each of these values has a count associated with it.

##['small' 'med' 'big']: This column contains 3 unique values: 'small,' 'med,' and 'big,' 
## and each of these values has a count associated with it.
## ['med' 'high' 'low']: This column contains 3 unique values: 'med,' 'high,' and 'low,' 
## and each of these values has a count associated with it.
## ['unacc' 'acc' 'vgood' 'good']: This column contains 4 unique values: 
##'unacc,' 'acc,' 'vgood,' and 'good,' and each of these values has a count of 4.

# %% [markdown]
# Check how these unique categories are distributed among the columns

# %%
for i in df.columns:
    print(df[i].value_counts())
    print()
# Out:
# high     432
# med      432
# low      432
# vhigh    431
# Name: buying, dtype: int64
#
# high     432
# med      432
# low      432
# vhigh    431
# Name: maintenance, dtype: int64
#
# 5    432
# 4    432
# 3    432
# 2    431
# Name: doors, dtype: int64
#
# more    576
# 4       576
# 2       575
# Name: persons, dtype: int64
#
# med      576
# big      576
# small    575
# Name: lug_boot, dtype: int64
#
# high    576
# med     576
# low     575
# Name: safety, dtype: int64
#
# unacc    1209
# acc       384
# good       69
# vgood      65
# Name: class, dtype: int64
